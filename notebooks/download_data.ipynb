# %%
import kagglehub
from pathlib import Path

# %%
data_path = Path("../data")

# %%
# https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud", output_dir=str(data_path / "creditcardfraud"))

# %%
# https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/

path = kagglehub.competition_download('house-prices-advanced-regression-techniques', output_dir=str(data_path / "house-prices"))
